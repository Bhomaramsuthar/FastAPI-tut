# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report,accuracy_score
import numpy as np

# %%
df = pd.read_csv('insurance.csv')

# %%
df.sample(5)
# Out:
#     age  weight  height  income_lpa  smoker    city      occupation  \
# 63   47    71.3    1.82       41.66    True    Gaya  business_owner
# 77   67   114.5    1.74        0.61    True  Mumbai         retired
# 3    22   109.4    1.55        3.34    True  Mumbai         student
# 9    58    74.4    1.73       43.07   False    Pune  business_owner
# 79   39    55.3    1.56       30.00    True  Indore  government_job
#
#    insurance_premium_category
# 63                       High
# 77                       High
# 3                      Medium
# 9                         Low
# 79                        Low

# %%
df['occupation'].unique()
# Out:
# array(['retired', 'freelancer', 'student', 'government_job',
#        'business_owner', 'unemployed', 'private_job'], dtype=object)

# %%
df_feat=df.copy()

# %%
df_feat["bmi"] = df_feat["weight"]/(df_feat["height"]**2)

# %%
def age_group(age):
    if age < 25:
        return "young"
    elif age < 45:
        return "adult"
    elif age < 60:
        return "middle_aged"
    else:
        return "senior"

# %%
df_feat["age_group"] = df_feat["age"].apply(age_group)

# %%
def lifestyle_risk(row):
    if row["smoker"] and row["bmi"] >30:
        return "high"
    elif row["smoker"] and row["bmi"]>27:
        return"meduim"
    else:
        return "low"

# %%
df_feat["lifestyle_risk"] = df_feat.apply(lifestyle_risk,axis=1)
